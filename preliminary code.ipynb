# %%
## You need to install NI-DAQmx runtime first (x64)
## Then, use pip install nidaqmx to install the library##

# %%
from nidaqmx.system import System
sys = System.local()
print([d.name for d in sys.devices])      # Result should be something like ['Dev1']
print("AI channels:", [c.name for c in sys.devices[0].ai_physical_chans])
# Out:
# ['Dev1']
# AI channels: ['Dev1/ai0', 'Dev1/ai1', 'Dev1/ai2', 'Dev1/ai3', 'Dev1/ai4', 'Dev1/ai5', 'Dev1/ai6', 'Dev1/ai7']

# %%
import nidaqmx
from nidaqmx.constants import TerminalConfiguration, AcquisitionType

DEV_CH   = "Dev1/ai0"                  # Channel Name
TERMINAL = TerminalConfiguration.DIFF  # Differential Reading (AI0 + and -)
FS       = 1000                        # Sample Rate [S/s]
N_PER    = 1000                        # Counts
CAL      = 100.0                       # e.g.: 1 V = 100 N

with nidaqmx.Task() as task:
    task.ai_channels.add_ai_voltage_chan(
        DEV_CH,
        min_val=-10.0, max_val=10.0,
        terminal_config=TERMINAL
    )
    task.timing.cfg_samp_clk_timing(FS, sample_mode=AcquisitionType.CONTINUOUS)

    print("Read Data (Ctrl+C to shut down)")
    while True:
        vals = task.read(number_of_samples_per_channel=N_PER)
        mean_v = sum(vals)/len(vals)
        forceN = mean_v * CAL
        print(f"{mean_v:.5f} V  →  {forceN:.3f} N")
# Out:
# Read Data (Ctrl+C to shut down)
# 0.06428 V  →  6.428 N
# 0.06433 V  →  6.433 N
# 0.06428 V  →  6.428 N
# 0.06413 V  →  6.413 N
# 0.06426 V  →  6.426 N
# 0.06427 V  →  6.427 N
# 0.06426 V  →  6.426 N
# 1.37928 V  →  137.928 N
# 2.39001 V  →  239.001 N
# 2.82854 V  →  282.854 N
# 1.75005 V  →  175.005 N
# 0.06411 V  →  6.411 N
# 0.06409 V  →  6.409 N
# 0.06394 V  →  6.394 N
# 0.06397 V  →  6.397 N
# 0.06392 V  →  6.392 N
# 0.06383 V  →  6.383 N
# 0.06419 V  →  6.419 N
# 0.06386 V  →  6.386 N
# 0.06387 V  →  6.387 N
# 0.06384 V  →  6.384 N
# 0.06378 V  →  6.378 N
# 0.06392 V  →  6.392 N
# 0.06384 V  →  6.384 N
# 0.06392 V  →  6.392 N
# 0.06394 V  →  6.394 N
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 20
#      18 print("Read Data (Ctrl+C to shut down)")
#      19 while True:
# ---> 20     vals = task.read(number_of_samples_per_channel=N_PER)
#      21     mean_v = sum(vals)/len(vals)
#      22     forceN = mean_v * CAL
#
# File c:\Users\eugene\AppData\Local\miniconda3\envs\ae100\lib\site-packages\nidaqmx\task\_task.py:620, in Task.read(self, number_of_samples_per_channel, timeout)
#     618     else:
#     619         data: numpy.typing.NDArray = numpy.zeros(array_shape, dtype=numpy.float64)
# --> 620         _, samples_read = self._interpreter.read_analog_f64(
#     621             self._handle,
#     622             number_of_samples_per_channel,
#     623             timeout,
#     624             FillMode.GROUP_BY_CHANNEL.value,
#     625             data,
#     626         )
#     628 elif (
#     629     read_chan_type == ChannelType.DIGITAL_INPUT
#     630     or read_chan_type == ChannelType.DIGITAL_OUTPUT
#     631 ):
#     632     if self.in_stream.di_num_booleans_per_chan == 1:
#
# File c:\Users\eugene\AppData\Local\miniconda3\envs\ae100\lib\site-packages\nidaqmx\_library_interpreter.py:4235, in LibraryInterpreter.read_analog_f64(self, task, num_samps_per_chan, timeout, fill_mode, read_array)
#    4227         if cfunc.argtypes is None:
#    4228             cfunc.argtypes = [
#    4229                 lib_importer.task_handle, ctypes.c_int,
#    4230                 ctypes.c_double, ctypes.c_int,
#    4231                 wrapped_ndpointer(dtype=numpy.float64,
#    4232                 flags=('C','W')), ctypes.c_uint,
#    4233                 ctypes.POINTER(ctypes.c_int), ctypes.POINTER(c_bool32)]
# -> 4235 error_code = cfunc(
#    4236     task, num_samps_per_chan, timeout, fill_mode, read_array,
#    4237     read_array.size, ctypes.byref(samps_per_chan_read), None)
#    4238 self.check_for_error(error_code, samps_per_chan_read=samps_per_chan_read.value)
#    4239 return read_array, samps_per_chan_read.value
#
# KeyboardInterrupt:

# %%
import nidaqmx
from nidaqmx.constants import TerminalConfiguration, AcquisitionType

DEV_CH   = "Dev1/ai0"                  # Channel Name
TERMINAL = TerminalConfiguration.DIFF  # Differential Reading (AI0 + and -)
FS       = 1000                        # Sample Rate [S/s]
N_PER    = 1000                        # Counts
CAL      = 20.306                       # e.g.: 1 V = 100 N
REST_V   = 0.0639

with nidaqmx.Task() as task:
    task.ai_channels.add_ai_voltage_chan(
        DEV_CH,
        min_val=-10.0, max_val=10.0,
        terminal_config=TERMINAL
    )
    task.timing.cfg_samp_clk_timing(FS, sample_mode=AcquisitionType.CONTINUOUS)

    print("Read Data (Ctrl+C to shut down)")
    while True:
        vals = task.read(number_of_samples_per_channel=N_PER)
        mean_v = sum(vals)/len(vals)
        forceN = mean_v * CAL - REST_V * CAL
        print(f"{mean_v:.5f} V  →  {forceN:.3f} N")
# Out:
# Read Data (Ctrl+C to shut down)
# 0.06386 V  →  -0.001 N
# 0.06381 V  →  -0.002 N
# 0.06387 V  →  -0.001 N
# 0.12040 V  →  1.147 N
# 0.17970 V  →  2.351 N
# 0.17969 V  →  2.351 N
# 0.17967 V  →  2.351 N
# 0.17966 V  →  2.351 N
# 0.15952 V  →  1.942 N
# 0.06388 V  →  -0.000 N
# 0.06403 V  →  0.003 N
# 0.12987 V  →  1.340 N
# 0.17320 V  →  2.219 N
# 0.17324 V  →  2.220 N
# 0.17326 V  →  2.221 N
# 0.17324 V  →  2.220 N
# 0.16890 V  →  2.132 N
# 0.06388 V  →  -0.000 N
# 0.06379 V  →  -0.002 N
# 0.06385 V  →  -0.001 N
# 0.08765 V  →  0.482 N
# 0.17009 V  →  2.156 N
# 0.17292 V  →  2.214 N
# 0.17279 V  →  2.211 N
# 0.17285 V  →  2.212 N
# 0.17296 V  →  2.215 N
# 0.17288 V  →  2.213 N
# 0.17292 V  →  2.214 N
# 0.17288 V  →  2.213 N
# 0.10687 V  →  0.873 N
# 0.06389 V  →  -0.000 N
# 0.06388 V  →  -0.000 N
# 0.14750 V  →  1.698 N
# 0.17832 V  →  2.323 N
# 0.17822 V  →  2.321 N
# 0.17818 V  →  2.320 N
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 21
#      19 print("Read Data (Ctrl+C to shut down)")
#      20 while True:
# ---> 21     vals = task.read(number_of_samples_per_channel=N_PER)
#      22     mean_v = sum(vals)/len(vals)
#      23     forceN = mean_v * CAL - REST_V * CAL
#
# File c:\Users\eugene\AppData\Local\miniconda3\envs\ae100\lib\site-packages\nidaqmx\task\_task.py:620, in Task.read(self, number_of_samples_per_channel, timeout)
#     618     else:
#     619         data: numpy.typing.NDArray = numpy.zeros(array_shape, dtype=numpy.float64)
# --> 620         _, samples_read = self._interpreter.read_analog_f64(
#     621             self._handle,
#     622             number_of_samples_per_channel,
#     623             timeout,
#     624             FillMode.GROUP_BY_CHANNEL.value,
#     625             data,
#     626         )
#     628 elif (
#     629     read_chan_type == ChannelType.DIGITAL_INPUT
#     630     or read_chan_type == ChannelType.DIGITAL_OUTPUT
#     631 ):
#     632     if self.in_stream.di_num_booleans_per_chan == 1:
#
# File c:\Users\eugene\AppData\Local\miniconda3\envs\ae100\lib\site-packages\nidaqmx\_library_interpreter.py:4235, in LibraryInterpreter.read_analog_f64(self, task, num_samps_per_chan, timeout, fill_mode, read_array)
#    4227         if cfunc.argtypes is None:
#    4228             cfunc.argtypes = [
#    4229                 lib_importer.task_handle, ctypes.c_int,
#    4230                 ctypes.c_double, ctypes.c_int,
#    4231                 wrapped_ndpointer(dtype=numpy.float64,
#    4232                 flags=('C','W')), ctypes.c_uint,
#    4233                 ctypes.POINTER(ctypes.c_int), ctypes.POINTER(c_bool32)]
# -> 4235 error_code = cfunc(
#    4236     task, num_samps_per_chan, timeout, fill_mode, read_array,
#    4237     read_array.size, ctypes.byref(samps_per_chan_read), None)
#    4238 self.check_for_error(error_code, samps_per_chan_read=samps_per_chan_read.value)
#    4239 return read_array, samps_per_chan_read.value
#
# KeyboardInterrupt:

# %%
print(8.6/35.274*9.80665)
print(8.7/35.274*9.80665)
# Out:
# 2.3909165390939497
# 2.4187178941996934

# %%
100/(11.772/2.3909)
# Out:
# 20.3100577641862

# %%
# daq_gui.py
# NI USB-6009 load-cell GUI (English UI)
# - Plot centered visually (symmetric padding + balanced subplot margins)
# - Dynamic font scaling buttons (A− / A+)
# - Sampling frequency label split into two lines
# - Gray dashed grid + thicker blue line
# - Safe close (after-cancel + double-call guard)
# - Auto-applied initial axes (X: 0–100 s, Y: -1–50 N)
# - "Logging interval [s]" -> samples_per_read = Fs * interval

import os, csv, time, datetime, threading, queue
import tkinter as tk
from tkinter import ttk, messagebox, font
import matplotlib
matplotlib.use("TkAgg")
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

import nidaqmx
from nidaqmx.constants import TerminalConfiguration, AcquisitionType

USB6009_FS_MAX = 48000.0  # guideline single-channel max S/s

class DAQApp:
    def __init__(self, root: tk.Tk):
        self.root = root
        self.root.title("NI USB-6009 Force Logger (Python)")
        self._closing = False
        self._after_id = None

        # ---------- Font system (dynamic) ----------
        self.base_size = 16
        self.FONT_NORM = font.Font(family="Arial", size=self.base_size)
        self.FONT_BIG  = font.Font(family="Arial", size=self.base_size, weight="bold")
        self.FONT_BTN  = font.Font(family="Arial", size=self.base_size, weight="bold")

        self.style = ttk.Style()
        try:
            self.style.theme_use("clam")
        except Exception:
            pass
        self.style.configure("Big.TButton", font=self.FONT_BTN, padding=14)
        self.style.configure("TCombobox",  font=self.FONT_NORM)
        self._apply_combobox_list_font()

        # ---------- State ----------
        self.running = False
        self.recording = False
        self.reader_stop = False
        self.task = None
        self.csv_writer = None
        self.csv_file = None
        self.t0 = None

        self.tare_v = 0.0
        self.cal = 100.0  # N/V
        self.q = queue.Queue(maxsize=64)
        self.t_data, self.f_data = [], []

        # ---------- Layout ----------==================================================================================================
        # Top controls frame
        frm = ttk.Frame(root, padding=20)
        frm.grid(row=0, column=0, sticky="nsew")
        # Plot frame with symmetric horizontal padding so the canvas looks centered
        self.plot_frame = ttk.Frame(root, padding=(20, 0, 20, 20))  # (left, top, right, bottom)
        self.plot_frame.grid(row=1, column=0, sticky="nsew")

        root.columnconfigure(0, weight=1)
        root.rowconfigure(1, weight=1)  # plot row expands

        PADX, PADY = 16, 10

        # Row 0: Device / Terminal / Voltage range + font scale buttons
        tk.Label(frm, text="Device/Channel", font=self.FONT_BIG)\
            .grid(row=0, column=0, sticky="w", padx=PADX, pady=PADY)
        self.e_chan = tk.Entry(frm, width=16, font=self.FONT_NORM)
        self.e_chan.insert(0, "Dev1/ai0")
        self.e_chan.grid(row=0, column=1, padx=PADX, pady=PADY)

        tk.Label(frm, text="Terminal", font=self.FONT_BIG)\
            .grid(row=0, column=2, sticky="e", padx=PADX, pady=PADY)
        self.cmb_term = ttk.Combobox(frm, width=10, values=["DIFF", "RSE"], state="readonly")
        self.cmb_term.set("DIFF")
        self.cmb_term.grid(row=0, column=3, padx=PADX, pady=PADY)

        tk.Label(frm, text="Voltage range [V]", font=self.FONT_BIG)\
            .grid(row=0, column=4, sticky="e", padx=PADX, pady=PADY)
        self.e_vmin = tk.Entry(frm, width=8, font=self.FONT_NORM); self.e_vmin.insert(0, "-10")
        self.e_vmax = tk.Entry(frm, width=8, font=self.FONT_NORM); self.e_vmax.insert(0, "10")
        self.e_vmin.grid(row=0, column=5, padx=PADX, pady=PADY)
        self.e_vmax.grid(row=0, column=6, padx=PADX, pady=PADY)

        # Font scaling buttons (A− / A+)
        self.btn_font_down = ttk.Button(frm, text="A−", style="Big.TButton",
                                        command=lambda: self.adjust_font(-2))
        self.btn_font_up   = ttk.Button(frm, text="A+", style="Big.TButton",
                                        command=lambda: self.adjust_font(+2))
        self.btn_font_down.grid(row=0, column=7, padx=PADX, pady=PADY, sticky="e")
        self.btn_font_up.grid(row=0, column=8, padx=(0, PADX), pady=PADY, sticky="w")

        # Row 1: Sampling frequency / Logging interval / Calibration
        sf_text = f"Sampling frequency [Samples/s]\n(≤ ~{int(USB6009_FS_MAX):,})"
        tk.Label(frm, text=sf_text, font=self.FONT_BIG, justify="left")\
            .grid(row=1, column=0, sticky="w", padx=PADX, pady=PADY)
        self.e_fs = tk.Entry(frm, width=10, font=self.FONT_NORM); self.e_fs.insert(0, "2000")
        self.e_fs.grid(row=1, column=1, padx=PADX, pady=PADY)

        tk.Label(frm, text="Logging interval [s]", font=self.FONT_BIG)\
            .grid(row=1, column=2, sticky="e", padx=PADX, pady=PADY)
        self.e_dt = tk.Entry(frm, width=10, font=self.FONT_NORM); self.e_dt.insert(0, "0.1")
        self.e_dt.grid(row=1, column=3, padx=PADX, pady=PADY)

        tk.Label(frm, text="Calibration (N/V)", font=self.FONT_BIG)\
            .grid(row=1, column=4, sticky="e", padx=PADX, pady=PADY)
        self.e_cal = tk.Entry(frm, width=10, font=self.FONT_NORM); self.e_cal.insert(0, str(self.cal))
        self.e_cal.grid(row=1, column=5, padx=PADX, pady=PADY)

        self.btn_apply = ttk.Button(frm, text="Apply", style="Big.TButton", command=self.apply_params)
        self.btn_apply.grid(row=1, column=6, padx=PADX, pady=PADY)

        # Row 2: X/Y ranges (manual zoom)
        tk.Label(frm, text="X Min [s]", font=self.FONT_BIG)\
            .grid(row=2, column=0, sticky="e", padx=PADX, pady=PADY)
        self.e_xmin = tk.Entry(frm, width=8, font=self.FONT_NORM); self.e_xmin.insert(0, "0")
        self.e_xmin.grid(row=2, column=1, padx=PADX, pady=PADY)

        tk.Label(frm, text="X Max [s]", font=self.FONT_BIG)\
            .grid(row=2, column=2, sticky="e", padx=PADX, pady=PADY)
        self.e_xmax = tk.Entry(frm, width=8, font=self.FONT_NORM); self.e_xmax.insert(0, "100")
        self.e_xmax.grid(row=2, column=3, padx=PADX, pady=PADY)

        self.btn_applyx = ttk.Button(frm, text="Apply X Range", style="Big.TButton",
                                     command=self.apply_xrange)
        self.btn_applyx.grid(row=2, column=4, padx=PADX, pady=PADY)

        tk.Label(frm, text="Y Min [N]", font=self.FONT_BIG)\
            .grid(row=2, column=5, sticky="e", padx=PADX, pady=PADY)
        self.e_ymin = tk.Entry(frm, width=8, font=self.FONT_NORM); self.e_ymin.insert(0, "-1")
        self.e_ymin.grid(row=2, column=6, padx=PADX, pady=PADY)

        tk.Label(frm, text="Y Max [N]", font=self.FONT_BIG)\
            .grid(row=2, column=7, sticky="e", padx=PADX, pady=PADY)
        self.e_ymax = tk.Entry(frm, width=8, font=self.FONT_NORM); self.e_ymax.insert(0, "50")
        self.e_ymax.grid(row=2, column=8, padx=PADX, pady=PADY)

        self.btn_applyy = ttk.Button(frm, text="Apply Y Range", style="Big.TButton",
                                     command=self.apply_yrange)
        self.btn_applyy.grid(row=2, column=9, padx=PADX, pady=PADY)

        # Row 3: Start/Stop/Tare/Record + CSV path
        self.btn_start = ttk.Button(frm, text="Start", style="Big.TButton", command=self.start)
        self.btn_start.grid(row=3, column=0, pady=PADY, sticky="ew")
        self.btn_stop  = ttk.Button(frm, text="Stop", style="Big.TButton",
                                    command=self.stop, state="disabled")
        self.btn_stop.grid(row=3, column=1, sticky="ew", pady=PADY)
        self.btn_tare  = ttk.Button(frm, text="Tare (Zero)", style="Big.TButton",
                                    command=self.do_tare, state="disabled")
        self.btn_tare.grid(row=3, column=2, sticky="ew", pady=PADY)
        self.btn_rec   = ttk.Button(frm, text="Record: OFF", style="Big.TButton",
                                    command=self.toggle_record, state="disabled")
        self.btn_rec.grid(row=3, column=3, sticky="ew", pady=PADY)

        tk.Label(frm, text="CSV:", font=self.FONT_BIG)\
            .grid(row=3, column=4, sticky="e", padx=PADX, pady=PADY)
        self.lbl_csv = tk.Label(frm, text="(not recording)", font=self.FONT_NORM, anchor="w")
        self.lbl_csv.grid(row=3, column=5, columnspan=4, sticky="w", padx=PADX, pady=PADY)

        # ---- Plot ----
        # Use constrained_layout to help centering within figure boundaries,
        # and also apply manual margins for balanced look.
        self.fig = plt.figure(figsize=(11, 5), dpi=100, constrained_layout=True)
        self.ax = self.fig.add_subplot(111)
        self.ax.set_xlabel("Time [s]", fontsize=16)
        self.ax.set_ylabel("Force [N]", fontsize=16)
        self.ax.tick_params(axis='both', labelsize=13)
        self.ax.grid(True, which="both", color="gray", linestyle="--", linewidth=0.6, alpha=0.5)
        self.line, = self.ax.plot([], [], color="blue", linewidth=2.2)

        # Initial axes
        try:
            self.ax.set_xlim(float(self.e_xmin.get()), float(self.e_xmax.get()))
            self.ax.set_ylim(float(self.e_ymin.get()), float(self.e_ymax.get()))
        except Exception:
            self.ax.set_xlim(0, 100)
            self.ax.set_ylim(-1, 50)

        # Canvas inside the centered plot_frame (with symmetric padding)
        self.canvas = FigureCanvasTkAgg(self.fig, master=self.plot_frame)
        self.canvas.get_tk_widget().grid(row=0, column=0, sticky="nsew")
        self.plot_frame.columnconfigure(0, weight=1)
        self.plot_frame.rowconfigure(0, weight=1)
        self.canvas.draw_idle()

        # Safe close
        root.protocol("WM_DELETE_WINDOW", self.on_close)
        # Periodic update
        self._schedule_update()

    #================================================================================================================

    # ---------- Internal helpers ----------
    def _apply_combobox_list_font(self):
        # Enlarge dropdown list font as well
        self.root.option_add("*TCombobox*Listbox*Font", ("Arial", 16))

    def _schedule_update(self):
        self._after_id = self.root.after(80, self.update_plot)

    def adjust_font(self, delta: int):
        # Update base size and apply to all font objects
        new_size = max(8, self.base_size + delta)
        if new_size == self.base_size:
            return
        self.base_size = new_size
        for f in (self.FONT_NORM, self.FONT_BIG, self.FONT_BTN):
            f.configure(size=self.base_size)

        # Re-apply combobox list font
        self._apply_combobox_list_font()

        # Update plot tick/label font sizes too
        self.ax.set_xlabel("Time [s]", fontsize=self.base_size + 0)
        self.ax.set_ylabel("Force [N]", fontsize=self.base_size + 0)
        self.ax.tick_params(axis='both', labelsize=max(8, self.base_size - 3))
        self.canvas.draw_idle()

    # ---------- Handlers ----------
    def apply_params(self):
        try:
            self.cal = float(self.e_cal.get())

            fs = float(self.e_fs.get())
            if fs <= 0:
                raise ValueError("Sampling frequency must be > 0.")
            if fs > USB6009_FS_MAX:
                messagebox.showwarning(
                    "Fs capped",
                    f"Sampling frequency exceeds device guideline (~{int(USB6009_FS_MAX):,} S/s). "
                    f"Capping to {int(USB6009_FS_MAX)}."
                )
                fs = USB6009_FS_MAX
                self.e_fs.delete(0, tk.END); self.e_fs.insert(0, str(int(fs)))

            dt = float(self.e_dt.get())
            if dt <= 0:
                raise ValueError("Logging interval must be > 0 s.")

            if self.running:
                messagebox.showinfo("Info", "Stop acquisition before applying parameters.")
        except Exception as e:
            messagebox.showerror("Parameter error", str(e))

    def apply_xrange(self):
        try:
            xmin = float(self.e_xmin.get())
            xmax = float(self.e_xmax.get())
            if xmin >= xmax:
                raise ValueError("X Min must be < X Max.")
            self.ax.set_xlim(xmin, xmax)
            self.canvas.draw_idle()
        except Exception as e:
            messagebox.showerror("X Range error", str(e))

    def apply_yrange(self):
        try:
            ymin = float(self.e_ymin.get())
            ymax = float(self.e_ymax.get())
            if ymin >= ymax:
                raise ValueError("Y Min must be < Y Max.")
            self.ax.set_ylim(ymin, ymax)
            self.canvas.draw_idle()
        except Exception as e:
            messagebox.showerror("Y Range error", str(e))

    def start(self):
        if self.running:
            return
        try:
            chan = self.e_chan.get().strip()

            fs = float(self.e_fs.get())
            if fs <= 0:
                raise ValueError("Sampling frequency must be > 0.")
            if fs > USB6009_FS_MAX:
                messagebox.showwarning(
                    "Fs capped",
                    f"Sampling frequency exceeds device guideline (~{int(USB6009_FS_MAX):,} S/s). "
                    f"Capping to {int(USB6009_FS_MAX)}."
                )
                fs = USB6009_FS_MAX
                self.e_fs.delete(0, tk.END); self.e_fs.insert(0, str(int(fs)))

            dt = float(self.e_dt.get())
            if dt <= 0:
                raise ValueError("Logging interval must be > 0 s.")

            nper = max(1, int(round(fs * dt)))  # samples per read

            vmin = float(self.e_vmin.get())
            vmax = float(self.e_vmax.get())
            term = TerminalConfiguration.DIFF if self.cmb_term.get() == "DIFF" \
                   else TerminalConfiguration.RSE
        except Exception as e:
            messagebox.showerror("Parameter error", str(e))
            return

        self.running = True
        self.recording = False
        self.reader_stop = False
        self.btn_start.config(state="disabled")
        self.btn_stop.config(state="normal")
        self.btn_tare.config(state="normal")
        self.btn_rec.config(state="normal", text="Record: OFF")
        self.lbl_csv.config(text="(not recording)")

        self.t_data.clear()
        self.f_data.clear()
        self.t0 = time.time()
        self.tare_v = 0.0

        # DAQ task
        self.task = nidaqmx.Task()
        self.task.ai_channels.add_ai_voltage_chan(
            chan, min_val=vmin, max_val=vmax, terminal_config=term
        )
        self.task.timing.cfg_samp_clk_timing(rate=fs, sample_mode=AcquisitionType.CONTINUOUS)

        # Background reader
        self.reader = threading.Thread(target=self._reader_loop, args=(nper, fs), daemon=True)
        self.reader.start()

    def stop(self):
        # stop recording
        self.recording = False
        self.btn_rec.config(text="Record: OFF")
        if self.csv_file:
            try:
                self.csv_file.close()
            except Exception:
                pass
            self.csv_writer = None
            self.csv_file = None
        self.lbl_csv.config(text="(not recording)")

        # stop reader/task
        self.reader_stop = True
        if self.task:
            try:
                self.task.close()
            except Exception:
                pass
            self.task = None

        self.running = False
        self.btn_start.config(state="normal")
        self.btn_stop.config(state="disabled")
        self.btn_tare.config(state="disabled")
        self.btn_rec.config(state="disabled")

    def do_tare(self):
        """Make the recent mean force go to zero by adjusting voltage offset."""
        if not self.f_data:
            self.tare_v = 0.0
            return
        window = self.f_data[-50:] if len(self.f_data) >= 50 else self.f_data
        mean_force = sum(window) / len(window) if window else 0.0
        self.tare_v += (mean_force / self.cal)  # force=(v-tare)*cal -> tare += mean/cal

    def toggle_record(self):
        if not self.running:
            return
        self.recording = not self.recording
        if self.recording:
            ts = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
            fname = f"daq_{ts}.csv"
            self.csv_file = open(fname, "w", newline="")
            self.csv_writer = csv.writer(self.csv_file)
            self.csv_writer.writerow(["t_sec", "voltage_V", "force_N"])
            self.lbl_csv.config(text=os.path.abspath(fname))
            self.btn_rec.config(text="Record: ON")
        else:
            if self.csv_file:
                try:
                    self.csv_file.close()
                except Exception:
                    pass
            self.csv_writer = None
            self.csv_file = None
            self.lbl_csv.config(text="(not recording)")
            self.btn_rec.config(text="Record: OFF")

    # ---------- Background reader ----------
    def _reader_loop(self, nper: int, fs: float):
        try:
            while not self.reader_stop:
                vals = self.task.read(number_of_samples_per_channel=nper)
                t_now = time.time() - self.t0
                v_mean = sum(vals) / len(vals) if vals else 0.0
                try:
                    self.q.put_nowait((t_now, v_mean))
                except queue.Full:
                    pass
                # small sleep (~5% of the logging interval) to reduce UI pressure
                interval = nper / fs if fs > 0 else 0.1
                time.sleep(max(0.0, interval * 0.05))
        except Exception as e:
            try:
                self.q.put(("__error__", str(e)))
            except Exception:
                pass

    # ---------- UI updater ----------
    def update_plot(self):
        while True:
            try:
                item = self.q.get_nowait()
            except queue.Empty:
                break

            if item[0] == "__error__":
                messagebox.showerror("DAQ error", item[1])
                self.stop()
                break

            t, v = item
            force = (v - self.tare_v) * self.cal
            self.t_data.append(t)
            self.f_data.append(force)

            if self.recording and self.csv_writer:
                self.csv_writer.writerow([f"{t:.6f}", f"{v:.6f}", f"{force:.6f}"])

        if self.t_data:
            self.line.set_data(self.t_data, self.f_data)
            # keep tick font in sync with UI size
            self.ax.tick_params(axis='both', labelsize=max(8, self.base_size - 3))
            self.canvas.draw_idle()

        self._schedule_update()

    # ---------- Safe close ----------
    def on_close(self):
        if self._closing:
            return
        self._closing = True

        try:
            if self.running:
                self.stop()
        except Exception:
            pass

        if self._after_id is not None:
            try:
                self.root.after_cancel(self._after_id)
            except Exception:
                pass
            self._after_id = None

        try:
            if self.root.winfo_exists():
                self.root.destroy()
        except Exception:
            pass


if __name__ == "__main__":
    root = tk.Tk()
    app = DAQApp(root)
    root.mainloop()

# %% [markdown]
# Run below code block (console command) to compile thrust_stand.py into Executable file.
#
# ```!pyinstaller --onefile --noconsole --copy-metadata nidaqmx --copy-metadata nitypes --name NI_USB6009_ForceLogger thrust_stand.py```

# %%
# !pyinstaller --onefile --noconsole --copy-metadata nidaqmx --copy-metadata nitypes --name NI_USB6009_ForceLogger thrust_stand.py
# Out:
# 987 INFO: PyInstaller: 6.16.0, contrib hooks: 2025.9
# 987 INFO: Python: 3.11.14 (conda)
# 1002 INFO: Platform: Windows-10-10.0.26200-SP0
# 1002 INFO: Python environment: C:\Users\eugene\AppData\Local\miniconda3\envs\ae100pypi
# 1004 INFO: wrote c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\NI_USB6009_ForceLogger.spec
# 1031 INFO: Module search paths (PYTHONPATH):
# ['C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Scripts\\pyinstaller.exe',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\python311.zip',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\DLLs',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\setuptools\\_vendor',
#  'c:\\Users\\eugene\\Documents\\School\\Fall_2025\\ae_100\\thrust stand demo '
#  'code']
# 2283 INFO: Appending 'datas' from .spec
# 2285 INFO: checking Analysis
# 2285 INFO: Building Analysis because Analysis-00.toc is non existent
# 2285 INFO: Looking for Python shared library...
# 2285 INFO: Using Python shared library: C:\Users\eugene\AppData\Local\miniconda3\envs\ae100pypi\python311.dll
# 2285 INFO: Running Analysis Analysis-00.toc
# 2285 INFO: Target bytecode optimization level: 0
# 2285 INFO: Initializing module dependency graph...
# 2285 INFO: Initializing module graph hook caches...
# 2386 INFO: Analyzing modules for base_library.zip ...
# 4944 INFO: Processing standard module hook 'hook-heapq.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 5136 INFO: Processing standard module hook 'hook-encodings.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 8690 INFO: Processing standard module hook 'hook-pickle.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 13760 INFO: Caching module dependency graph...
# 13816 INFO: Analyzing c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\thrust_stand.py
# 13859 INFO: Processing pre-find-module-path hook 'hook-tkinter.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path'
# 13866 INFO: TclTkInfo: initializing cached Tcl/Tk info...
# 14302 INFO: Processing standard module hook 'hook-_tkinter.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 14460 INFO: Processing standard module hook 'hook-matplotlib.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 15187 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 15192 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 22450 INFO: Processing standard module hook 'hook-numpy.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 24375 INFO: Processing standard module hook 'hook-difflib.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 25225 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 25945 INFO: Processing standard module hook 'hook-xml.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 27337 INFO: Processing standard module hook 'hook-_ctypes.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 29598 INFO: Processing standard module hook 'hook-sysconfig.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 29807 INFO: Processing standard module hook 'hook-platform.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 31422 INFO: Processing standard module hook 'hook-psutil.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 33852 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 35509 INFO: Processing standard module hook 'hook-charset_normalizer.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 36250 INFO: Processing pre-safe-import-module hook 'hook-gi.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 36743 INFO: Processing standard module hook 'hook-matplotlib.backend_bases.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 37060 INFO: Processing standard module hook 'hook-PIL.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 37302 INFO: Processing standard module hook 'hook-PIL.Image.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 38282 INFO: Processing standard module hook 'hook-xml.etree.cElementTree.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 38498 INFO: Processing standard module hook 'hook-xml.dom.domreg.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 39523 INFO: Processing standard module hook 'hook-PIL.ImageFilter.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 41365 INFO: Processing standard module hook 'hook-jinja2.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 42860 INFO: Processing standard module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 43015 INFO: Processing standard module hook 'hook-matplotlib.pyplot.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 45183 INFO: Processing standard module hook 'hook-dateutil.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 45368 INFO: Processing pre-safe-import-module hook 'hook-six.moves.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 50912 INFO: Processing standard module hook 'hook-certifi.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 53045 INFO: Processing standard module hook 'hook-zoneinfo.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 55996 INFO: Processing pre-safe-import-module hook 'hook-importlib_metadata.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 55998 INFO: Setuptools: 'importlib_metadata' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.importlib_metadata'!
# 56025 INFO: Processing standard module hook 'hook-setuptools.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 56082 INFO: Processing pre-safe-import-module hook 'hook-distutils.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 56082 INFO: Processing pre-find-module-path hook 'hook-distutils.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path'
# 56591 INFO: Processing standard module hook 'hook-distutils.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 56683 INFO: Processing standard module hook 'hook-distutils.util.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 56824 INFO: Processing standard module hook 'hook-_osx_support.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 57297 INFO: Processing pre-safe-import-module hook 'hook-jaraco.text.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 57299 INFO: Setuptools: 'jaraco.text' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.jaraco.text'!
# 57335 INFO: Processing standard module hook 'hook-setuptools._vendor.jaraco.text.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 57335 INFO: Processing pre-safe-import-module hook 'hook-importlib_resources.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 57339 INFO: Processing pre-safe-import-module hook 'hook-jaraco.functools.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 57339 INFO: Setuptools: 'jaraco.functools' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.jaraco.functools'!
# 57366 INFO: Processing pre-safe-import-module hook 'hook-more_itertools.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 57366 INFO: Setuptools: 'more_itertools' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.more_itertools'!
# 57614 INFO: Processing pre-safe-import-module hook 'hook-jaraco.context.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 57623 INFO: Setuptools: 'jaraco.context' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.jaraco.context'!
# 57666 INFO: Processing pre-safe-import-module hook 'hook-backports.tarfile.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 57666 INFO: Setuptools: 'backports.tarfile' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.backports.tarfile'!
# 57815 INFO: Processing standard module hook 'hook-backports.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 58846 INFO: Processing pre-safe-import-module hook 'hook-tomli.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 58846 INFO: Setuptools: 'tomli' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.tomli'!
# 60239 INFO: Processing pre-safe-import-module hook 'hook-wheel.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 60994 INFO: Processing standard module hook 'hook-setuptools._vendor.importlib_metadata.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 61002 INFO: Processing pre-safe-import-module hook 'hook-zipp.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 61002 INFO: Setuptools: 'zipp' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.zipp'!
# 61123 INFO: Processing module hooks (post-graph stage)...
# 61154 INFO: Processing standard module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 61154 INFO: Matplotlib backend selection method: automatic discovery of used backends
# 61230 INFO: Discovered Matplotlib backend(s) via `matplotlib.use()` call in module 'C:\\Users\\eugene\\Documents\\School\\Fall_2025\\ae_100\\thrust stand demo code\\thrust_stand.py': ['TkAgg']
# 61230 INFO: The following Matplotlib backends were discovered by scanning for `matplotlib.use()` calls: ['TkAgg']. If your backend of choice is not in this list, either add a `matplotlib.use()` call to your code, or configure the backend collection via hook options (see: https://pyinstaller.org/en/stable/hooks-config.html#matplotlib-hooks).
# 61230 INFO: Selected matplotlib backends: ['TkAgg']
# 62095 INFO: Processing standard module hook 'hook-PIL.SpiderImagePlugin.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 63925 INFO: Processing standard module hook 'hook-_tkinter.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 63925 INFO: Processing standard module hook 'hook-tzdata.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 65106 INFO: Performing binary vs. data reclassification (1756 entries)
# 77874 INFO: Looking for ctypes DLLs
# 78230 INFO: Analyzing run-time hooks ...
# 78237 INFO: Including run-time hook 'pyi_rth_inspect.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 78256 INFO: Including run-time hook 'pyi_rth_setuptools.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 78258 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 78276 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 78291 INFO: Including run-time hook 'pyi_rth_mplconfig.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 78299 INFO: Processing pre-find-module-path hook 'hook-_pyi_rth_utils.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path'
# 78320 INFO: Processing standard module hook 'hook-_pyi_rth_utils.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks'
# 78351 INFO: Including run-time hook 'pyi_rth__tkinter.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 78446 INFO: Creating base_library.zip...
# 78477 INFO: Looking for dynamic libraries
# 81021 INFO: Extra DLL search directories (AddDllDirectory): ['C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100pypi\\Lib\\site-packages\\numpy.libs']
# 81021 INFO: Extra DLL search directories (PATH): []
# 83862 INFO: Warnings written to c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\build\NI_USB6009_ForceLogger\warn-NI_USB6009_ForceLogger.txt
# 84132 INFO: Graph cross-reference written to c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\build\NI_USB6009_ForceLogger\xref-NI_USB6009_ForceLogger.html
# 84354 INFO: checking PYZ
# 84354 INFO: Building PYZ because PYZ-00.toc is non existent
# 84354 INFO: Building PYZ (ZlibArchive) c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\build\NI_USB6009_ForceLogger\PYZ-00.pyz
# 86791 INFO: Building PYZ (ZlibArchive) c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\build\NI_USB6009_ForceLogger\PYZ-00.pyz completed successfully.
# 86961 INFO: checking PKG
# 86966 INFO: Building PKG because PKG-00.toc is non existent
# 86966 INFO: Building PKG (CArchive) NI_USB6009_ForceLogger.pkg
# 106243 INFO: Building PKG (CArchive) NI_USB6009_ForceLogger.pkg completed successfully.
# 106340 INFO: Bootloader C:\Users\eugene\AppData\Local\miniconda3\envs\ae100pypi\Lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\runw.exe
# 106340 INFO: checking EXE
# 106340 INFO: Building EXE because EXE-00.toc is non existent
# 106340 INFO: Building EXE from EXE-00.toc
# 106340 INFO: Copying bootloader EXE to c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\dist\NI_USB6009_ForceLogger.exe
# 106494 INFO: Copying icon to EXE
# 106574 INFO: Copying 0 resources to EXE
# 106574 INFO: Embedding manifest in EXE
# 106584 INFO: Appending PKG archive to EXE
# 106781 INFO: Fixing EXE headers
# 112526 INFO: Building EXE from EXE-00.toc completed successfully.
# 112604 INFO: Build complete! The results are available in: c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\dist

# %% [markdown]
# This code block will include ALL dependencies of nidaqmx, including stuff not needed. This can produce enormous file sizes (4x what is actually needed). Only use this if the above block doesn't work.

# %%
# !pyinstaller --onefile --noconsole --recursive-copy-metadata nidaqmx --name NI_USB6009_ForceLogger thrust_stand.py
# Out:
# 12028 INFO: PyInstaller: 6.16.0, contrib hooks: 2025.9
# 12028 INFO: Python: 3.10.19 (conda)
# 12052 INFO: Platform: Windows-10-10.0.26200-SP0
# 12052 INFO: Python environment: C:\Users\eugene\AppData\Local\miniconda3\envs\ae100
# 12058 INFO: wrote c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\NI_USB6009_ForceLogger.spec
# 12697 INFO: Module search paths (PYTHONPATH):
# ['C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\Scripts\\pyinstaller.exe',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\python310.zip',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\DLLs',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\win32',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\setuptools\\_vendor',
#  'c:\\Users\\eugene\\Documents\\School\\Fall_2025\\ae_100\\thrust stand demo '
#  'code']
# 21395 INFO: Appending 'datas' from .spec
# 21436 INFO: checking Analysis
# 21436 INFO: Building Analysis because Analysis-00.toc is non existent
# 21438 INFO: Looking for Python shared library...
# 21438 INFO: Using Python shared library: C:\Users\eugene\AppData\Local\miniconda3\envs\ae100\python310.dll
# 21439 INFO: Running Analysis Analysis-00.toc
# 21439 INFO: Target bytecode optimization level: 0
# 21439 INFO: Initializing module dependency graph...
# 21440 INFO: Initializing module graph hook caches...
# 21664 INFO: Analyzing modules for base_library.zip ...
# 29373 INFO: Processing standard module hook 'hook-heapq.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 29705 INFO: Processing standard module hook 'hook-encodings.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 36879 INFO: Processing standard module hook 'hook-pickle.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 44209 INFO: Caching module dependency graph...
# 44410 INFO: Analyzing c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\thrust_stand.py
# 44529 INFO: Processing pre-find-module-path hook 'hook-tkinter.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path'
# 44529 INFO: TclTkInfo: initializing cached Tcl/Tk info...
# 45522 INFO: Processing standard module hook 'hook-_tkinter.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 45793 INFO: Processing standard module hook 'hook-matplotlib.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 47891 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 47891 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 64020 INFO: Processing standard module hook 'hook-numpy.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 64161 WARNING: Conda distribution '__win', dependency of 'numpy', was not found. If you installed this distribution with pip then you may ignore this warning.
# 65721 INFO: Processing standard module hook 'hook-platform.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 66453 INFO: Processing standard module hook 'hook-sysconfig.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 69769 INFO: Processing standard module hook 'hook-difflib.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 70671 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 70989 INFO: Processing standard module hook 'hook-xml.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 71901 INFO: Processing standard module hook 'hook-_ctypes.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 74657 INFO: Processing standard module hook 'hook-psutil.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 77581 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 79681 INFO: Processing standard module hook 'hook-charset_normalizer.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 80729 INFO: Processing pre-safe-import-module hook 'hook-gi.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 81267 INFO: Processing standard module hook 'hook-matplotlib.backend_bases.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 81594 INFO: Processing standard module hook 'hook-PIL.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 81733 INFO: Processing standard module hook 'hook-PIL.Image.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 84540 INFO: Processing standard module hook 'hook-xml.etree.cElementTree.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 84789 INFO: Processing standard module hook 'hook-xml.dom.domreg.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 86163 INFO: Processing standard module hook 'hook-PIL.ImageFilter.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 88504 INFO: Processing standard module hook 'hook-jinja2.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 90606 INFO: Processing standard module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 90850 INFO: Processing standard module hook 'hook-matplotlib.pyplot.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 93598 INFO: Processing standard module hook 'hook-dateutil.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 93932 INFO: Processing pre-safe-import-module hook 'hook-six.moves.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 102608 INFO: Processing standard module hook 'hook-certifi.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 106210 INFO: Processing standard module hook 'hook-zoneinfo.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 110393 INFO: Processing pre-safe-import-module hook 'hook-importlib_metadata.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 110488 INFO: Processing standard module hook 'hook-importlib_metadata.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 110833 INFO: Processing pre-safe-import-module hook 'hook-zipp.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 111100 INFO: Processing module hooks (post-graph stage)...
# 111159 INFO: Processing standard module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 111162 INFO: Matplotlib backend selection method: automatic discovery of used backends
# 111204 INFO: Discovered Matplotlib backend(s) via `matplotlib.use()` call in module 'C:\\Users\\eugene\\Documents\\School\\Fall_2025\\ae_100\\thrust stand demo code\\thrust_stand.py': ['TkAgg']
# 111204 INFO: The following Matplotlib backends were discovered by scanning for `matplotlib.use()` calls: ['TkAgg']. If your backend of choice is not in this list, either add a `matplotlib.use()` call to your code, or configure the backend collection via hook options (see: https://pyinstaller.org/en/stable/hooks-config.html#matplotlib-hooks).
# 111204 INFO: Selected matplotlib backends: ['TkAgg']
# 114181 INFO: Processing standard module hook 'hook-PIL.SpiderImagePlugin.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 114646 INFO: Processing standard module hook 'hook-_tkinter.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 114651 INFO: Processing standard module hook 'hook-tzdata.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 120863 INFO: Performing binary vs. data reclassification (1976 entries)
# 168657 INFO: Looking for ctypes DLLs
# 168881 INFO: Analyzing run-time hooks ...
# 168900 INFO: Including run-time hook 'pyi_rth_inspect.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 168941 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 168977 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 169011 INFO: Including run-time hook 'pyi_rth_mplconfig.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 169042 INFO: Processing pre-find-module-path hook 'hook-_pyi_rth_utils.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path'
# 169082 INFO: Processing standard module hook 'hook-_pyi_rth_utils.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks'
# 169167 INFO: Including run-time hook 'pyi_rth__tkinter.py' from 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 169539 INFO: Creating base_library.zip...
# 169655 INFO: Looking for dynamic libraries
# 176384 INFO: Extra DLL search directories (AddDllDirectory): []
# 176384 INFO: Extra DLL search directories (PATH): []
# 186679 WARNING: Library not found: could not resolve 'mkl_rt.dll', dependency of 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\Library\\bin\\libcblas.dll'.
# 186679 WARNING: Library not found: could not resolve 'msmpi.dll', dependency of 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\Library\\bin\\mkl_blacs_msmpi_lp64.2.dll'.
# 186679 WARNING: Library not found: could not resolve 'mkl_rt.dll', dependency of 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\Library\\bin\\liblapack.dll'.
# 186686 WARNING: Library not found: could not resolve 'msmpi.dll', dependency of 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\Library\\bin\\mkl_blacs_msmpi_ilp64.2.dll'.
# 186687 WARNING: Library not found: could not resolve 'mkl_rt.dll', dependency of 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\Library\\bin\\libblas.dll'.
# 186687 WARNING: Library not found: could not resolve 'impi.dll', dependency of 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\Library\\bin\\mkl_blacs_intelmpi_ilp64.2.dll'.
# 186687 WARNING: Library not found: could not resolve 'impi.dll', dependency of 'C:\\Users\\eugene\\AppData\\Local\\miniconda3\\envs\\ae100\\Library\\bin\\mkl_blacs_intelmpi_lp64.2.dll'.
# 187100 INFO: Warnings written to c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\build\NI_USB6009_ForceLogger\warn-NI_USB6009_ForceLogger.txt
# 187736 INFO: Graph cross-reference written to c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\build\NI_USB6009_ForceLogger\xref-NI_USB6009_ForceLogger.html
# 188409 INFO: checking PYZ
# 188409 INFO: Building PYZ because PYZ-00.toc is non existent
# 188409 INFO: Building PYZ (ZlibArchive) c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\build\NI_USB6009_ForceLogger\PYZ-00.pyz
# 190229 INFO: Building PYZ (ZlibArchive) c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\build\NI_USB6009_ForceLogger\PYZ-00.pyz completed successfully.
# 190582 INFO: checking PKG
# 190582 INFO: Building PKG because PKG-00.toc is non existent
# 190582 INFO: Building PKG (CArchive) NI_USB6009_ForceLogger.pkg
# 305710 INFO: Building PKG (CArchive) NI_USB6009_ForceLogger.pkg completed successfully.
# 305929 INFO: Bootloader C:\Users\eugene\AppData\Local\miniconda3\envs\ae100\lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\runw.exe
# 305929 INFO: checking EXE
# 305931 INFO: Building EXE because EXE-00.toc is non existent
# 305931 INFO: Building EXE from EXE-00.toc
# 305931 INFO: Copying bootloader EXE to c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\dist\NI_USB6009_ForceLogger.exe
# 306253 INFO: Copying icon to EXE
# 306456 INFO: Copying 0 resources to EXE
# 306456 INFO: Embedding manifest in EXE
# 306473 INFO: Appending PKG archive to EXE
# 306955 INFO: Fixing EXE headers
# 358367 INFO: Building EXE from EXE-00.toc completed successfully.
# 358499 INFO: Build complete! The results are available in: c:\Users\eugene\Documents\School\Fall_2025\ae_100\thrust stand demo code\dist
